# %% [markdown]
# <a href="https://www.kaggle.com/code/nawrozmohammadi/bbox-attention-head-fused?scriptVersionId=314581581" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# from google.colab import drive
import os
import matplotlib.pyplot as plt
import matplotlib.image as pltimg
import numpy as np
import pandas as pd
import cv2
import torch
import re
from PIL import Image
import torchvision
from torchvision import transforms
from torch import nn
from time import time
import albumentations as A
from torchsummary import summary
import gdown

# %%
# check if the gpu is available or not
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
# download the dataset from google drive
file_id = '1cubZJ0Mg98KgsefdXQiY8TxD9XVVjxM2'
url = f'https://drive.google.com/uc?id={file_id}'
gdown.download(url, 'file.zip', quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1cubZJ0Mg98KgsefdXQiY8TxD9XVVjxM2
# From (redirected): https://drive.google.com/uc?id=1cubZJ0Mg98KgsefdXQiY8TxD9XVVjxM2&confirm=t&uuid=7c2af87e-d3a6-4835-9fae-ab232a99e237
# To: /kaggle/working/file.zip
# 100%|██████████| 167M/167M [00:01<00:00, 122MB/s]
# 'file.zip'

# %%
# !unzip file.zip -d /kaggle/working/data/
# Out:
# Archive:  file.zip
#    creating: /kaggle/working/data/benign_mask/
#   inflating: /kaggle/working/data/benign_mask/benign (1)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (10)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (100)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (100)_mask_1.png
#   inflating: /kaggle/working/data/benign_mask/benign (101)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (102)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (103)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (104)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (105)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (106)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (107)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (108)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (109)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (11)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (110)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (111)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (112)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (113)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (114)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (115)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (116)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (117)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (118)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (119)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (12)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (120)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (121)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (122)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (123)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (124)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (125)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (126)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (127)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (128)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (129)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (13)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (130)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (131)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (132)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (133)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (134)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (135)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (136)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (137)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (138)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (139)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (14)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (140)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (141)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (142)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (143)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (144)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (145)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (146)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (147)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (148)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (149)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (15)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (150)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (151)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (152)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (153)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (154)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (155)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (156)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (157)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (158)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (159)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (16)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (160)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (161)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (162)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (163)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (163)_mask_1.png
#   inflating: /kaggle/working/data/benign_mask/benign (164)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (165)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (166)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (167)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (168)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (169)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (17)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (170)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (171)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (172)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (173)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (173)_mask_1.png
#   inflating: /kaggle/working/data/benign_mask/benign (174)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (175)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (176)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (177)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (178)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (179)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (18)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (180)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (181)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (181)_mask_1.png
#   inflating: /kaggle/working/data/benign_mask/benign (182)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (183)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (184)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (185)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (186)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (187)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (188)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (189)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (19)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (190)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (191)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (192)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (193)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (194)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (195)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (195)_mask_1.png
#   inflating: /kaggle/working/data/benign_mask/benign (195)_mask_2.png
#   inflating: /kaggle/working/data/benign_mask/benign (196)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (197)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (198)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (199)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (2)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (20)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (200)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (201)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (202)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (203)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (204)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (205)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (206)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (207)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (208)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (209)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (21)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (210)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (211)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (212)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (213)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (214)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (215)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (216)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (217)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (218)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (219)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (22)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (220)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (221)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (222)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (223)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (224)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (225)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (226)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (227)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (228)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (229)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (23)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (230)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (231)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (232)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (233)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (234)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (235)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (236)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (237)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (238)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (239)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (24)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (240)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (241)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (242)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (243)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (244)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (245)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (246)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (247)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (248)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (249)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (25)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (25)_mask_1.png
#   inflating: /kaggle/working/data/benign_mask/benign (250)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (251)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (252)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (253)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (254)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (255)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (256)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (257)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (258)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (259)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (26)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (260)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (261)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (262)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (263)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (264)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (265)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (266)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (267)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (268)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (269)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (27)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (270)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (271)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (272)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (273)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (274)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (275)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (276)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (277)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (278)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (279)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (28)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (280)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (281)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (282)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (283)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (284)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (285)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (286)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (287)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (288)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (289)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (29)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (290)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (291)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (292)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (293)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (294)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (295)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (296)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (297)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (298)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (299)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (3)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (30)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (300)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (301)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (302)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (303)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (304)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (305)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (306)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (307)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (308)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (309)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (31)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (310)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (311)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (312)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (313)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (314)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (315)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (315)_mask_1.png
#   inflating: /kaggle/working/data/benign_mask/benign (316)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (317)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (318)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (319)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (32)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (320)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (321)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (322)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (323)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (324)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (325)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (326)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (327)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (328)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (329)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (33)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (330)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (331)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (332)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (333)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (334)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (335)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (336)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (337)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (338)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (339)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (34)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (340)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (341)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (342)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (343)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (344)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (345)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (346)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (346)_mask_1.png
#   inflating: /kaggle/working/data/benign_mask/benign (347)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (348)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (349)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (35)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (350)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (351)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (352)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (353)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (354)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (355)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (356)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (357)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (358)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (359)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (36)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (360)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (361)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (362)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (363)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (364)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (365)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (366)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (367)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (368)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (369)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (37)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (370)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (371)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (372)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (373)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (374)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (375)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (376)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (377)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (378)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (379)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (38)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (380)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (381)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (382)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (383)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (384)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (385)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (386)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (387)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (388)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (389)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (39)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (390)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (391)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (392)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (393)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (394)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (395)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (396)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (397)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (398)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (399)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (4)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (4)_mask_1.png
#   inflating: /kaggle/working/data/benign_mask/benign (40)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (400)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (401)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (402)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (403)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (404)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (405)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (406)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (407)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (408)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (409)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (41)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (410)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (411)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (412)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (413)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (414)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (415)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (416)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (417)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (418)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (419)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (42)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (420)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (421)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (422)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (423)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (424)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (424)_mask_1.png
#   inflating: /kaggle/working/data/benign_mask/benign (425)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (426)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (427)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (428)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (429)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (43)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (430)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (431)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (432)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (433)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (434)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (435)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (436)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (437)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (44)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (45)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (46)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (47)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (48)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (49)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (5)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (50)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (51)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (52)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (53)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (54)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (54)_mask_1.png
#   inflating: /kaggle/working/data/benign_mask/benign (55)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (56)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (57)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (58)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (58)_mask_1.png
#   inflating: /kaggle/working/data/benign_mask/benign (59)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (6)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (60)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (61)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (62)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (63)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (64)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (65)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (66)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (67)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (68)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (69)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (7)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (70)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (71)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (72)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (73)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (74)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (75)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (76)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (77)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (78)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (79)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (8)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (80)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (81)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (82)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (83)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (83)_mask_1.png
#   inflating: /kaggle/working/data/benign_mask/benign (84)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (85)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (86)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (87)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (88)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (89)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (9)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (90)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (91)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (92)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (92)_mask_1.png
#   inflating: /kaggle/working/data/benign_mask/benign (93)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (93)_mask_1.png
#   inflating: /kaggle/working/data/benign_mask/benign (94)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (95)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (96)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (97)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (98)_mask.png
#   inflating: /kaggle/working/data/benign_mask/benign (98)_mask_1.png
#   inflating: /kaggle/working/data/benign_mask/benign (99)_mask.png
#   inflating: /kaggle/working/data/benign_mask/desktop.ini
#    creating: /kaggle/working/data/benign/
#   inflating: /kaggle/working/data/benign/benign (1).png
#   inflating: /kaggle/working/data/benign/benign (10).png
#   inflating: /kaggle/working/data/benign/benign (100).png
#   inflating: /kaggle/working/data/benign/benign (101).png
#   inflating: /kaggle/working/data/benign/benign (102).png
#   inflating: /kaggle/working/data/benign/benign (103).png
#   inflating: /kaggle/working/data/benign/benign (104).png
#   inflating: /kaggle/working/data/benign/benign (105).png
#   inflating: /kaggle/working/data/benign/benign (106).png
#   inflating: /kaggle/working/data/benign/benign (107).png
#   inflating: /kaggle/working/data/benign/benign (108).png
#   inflating: /kaggle/working/data/benign/benign (109).png
#   inflating: /kaggle/working/data/benign/benign (11).png
#   inflating: /kaggle/working/data/benign/benign (110).png
#   inflating: /kaggle/working/data/benign/benign (111).png
#   inflating: /kaggle/working/data/benign/benign (112).png
#   inflating: /kaggle/working/data/benign/benign (113).png
#   inflating: /kaggle/working/data/benign/benign (114).png
#   inflating: /kaggle/working/data/benign/benign (115).png
#   inflating: /kaggle/working/data/benign/benign (116).png
#   inflating: /kaggle/working/data/benign/benign (117).png
#   inflating: /kaggle/working/data/benign/benign (118).png
#   inflating: /kaggle/working/data/benign/benign (119).png
#   inflating: /kaggle/working/data/benign/benign (12).png
#   inflating: /kaggle/working/data/benign/benign (120).png
#   inflating: /kaggle/working/data/benign/benign (121).png
#   inflating: /kaggle/working/data/benign/benign (122).png
#   inflating: /kaggle/working/data/benign/benign (123).png
#   inflating: /kaggle/working/data/benign/benign (124).png
#   inflating: /kaggle/working/data/benign/benign (125).png
#   inflating: /kaggle/working/data/benign/benign (126).png
#   inflating: /kaggle/working/data/benign/benign (127).png
#   inflating: /kaggle/working/data/benign/benign (128).png
#   inflating: /kaggle/working/data/benign/benign (129).png
#   inflating: /kaggle/working/data/benign/benign (13).png
#   inflating: /kaggle/working/data/benign/benign (130).png
#   inflating: /kaggle/working/data/benign/benign (131).png
#   inflating: /kaggle/working/data/benign/benign (132).png
#   inflating: /kaggle/working/data/benign/benign (133).png
#   inflating: /kaggle/working/data/benign/benign (134).png
#   inflating: /kaggle/working/data/benign/benign (135).png
#   inflating: /kaggle/working/data/benign/benign (136).png
#   inflating: /kaggle/working/data/benign/benign (137).png
#   inflating: /kaggle/working/data/benign/benign (138).png
#   inflating: /kaggle/working/data/benign/benign (139).png
#   inflating: /kaggle/working/data/benign/benign (14).png
#   inflating: /kaggle/working/data/benign/benign (140).png
#   inflating: /kaggle/working/data/benign/benign (141).png
#   inflating: /kaggle/working/data/benign/benign (142).png
#   inflating: /kaggle/working/data/benign/benign (143).png
#   inflating: /kaggle/working/data/benign/benign (144).png
#   inflating: /kaggle/working/data/benign/benign (145).png
#   inflating: /kaggle/working/data/benign/benign (146).png
#   inflating: /kaggle/working/data/benign/benign (147).png
#   inflating: /kaggle/working/data/benign/benign (148).png
#   inflating: /kaggle/working/data/benign/benign (149).png
#   inflating: /kaggle/working/data/benign/benign (15).png
#   inflating: /kaggle/working/data/benign/benign (150).png
#   inflating: /kaggle/working/data/benign/benign (151).png
#   inflating: /kaggle/working/data/benign/benign (152).png
#   inflating: /kaggle/working/data/benign/benign (153).png
#   inflating: /kaggle/working/data/benign/benign (154).png
#   inflating: /kaggle/working/data/benign/benign (155).png
#   inflating: /kaggle/working/data/benign/benign (156).png
#   inflating: /kaggle/working/data/benign/benign (157).png
#   inflating: /kaggle/working/data/benign/benign (158).png
#   inflating: /kaggle/working/data/benign/benign (159).png
#   inflating: /kaggle/working/data/benign/benign (16).png
#   inflating: /kaggle/working/data/benign/benign (160).png
#   inflating: /kaggle/working/data/benign/benign (161).png
#   inflating: /kaggle/working/data/benign/benign (162).png
#   inflating: /kaggle/working/data/benign/benign (163).png
#   inflating: /kaggle/working/data/benign/benign (164).png
#   inflating: /kaggle/working/data/benign/benign (165).png
#   inflating: /kaggle/working/data/benign/benign (166).png
#   inflating: /kaggle/working/data/benign/benign (167).png
#   inflating: /kaggle/working/data/benign/benign (168).png
#   inflating: /kaggle/working/data/benign/benign (169).png
#   inflating: /kaggle/working/data/benign/benign (17).png
#   inflating: /kaggle/working/data/benign/benign (170).png
#   inflating: /kaggle/working/data/benign/benign (171).png
#   inflating: /kaggle/working/data/benign/benign (172).png
#   inflating: /kaggle/working/data/benign/benign (173).png
#   inflating: /kaggle/working/data/benign/benign (174).png
#   inflating: /kaggle/working/data/benign/benign (175).png
#   inflating: /kaggle/working/data/benign/benign (176).png
#   inflating: /kaggle/working/data/benign/benign (177).png
#   inflating: /kaggle/working/data/benign/benign (178).png
#   inflating: /kaggle/working/data/benign/benign (179).png
#   inflating: /kaggle/working/data/benign/benign (18).png
#   inflating: /kaggle/working/data/benign/benign (180).png
#   inflating: /kaggle/working/data/benign/benign (181).png
#   inflating: /kaggle/working/data/benign/benign (182).png
#   inflating: /kaggle/working/data/benign/benign (183).png
#   inflating: /kaggle/working/data/benign/benign (184).png
#   inflating: /kaggle/working/data/benign/benign (185).png
#   inflating: /kaggle/working/data/benign/benign (186).png
#   inflating: /kaggle/working/data/benign/benign (187).png
#   inflating: /kaggle/working/data/benign/benign (188).png
#   inflating: /kaggle/working/data/benign/benign (189).png
#   inflating: /kaggle/working/data/benign/benign (19).png
#   inflating: /kaggle/working/data/benign/benign (190).png
#   inflating: /kaggle/working/data/benign/benign (191).png
#   inflating: /kaggle/working/data/benign/benign (192).png
#   inflating: /kaggle/working/data/benign/benign (193).png
#   inflating: /kaggle/working/data/benign/benign (194).png
#   inflating: /kaggle/working/data/benign/benign (195).png
#   inflating: /kaggle/working/data/benign/benign (196).png
#   inflating: /kaggle/working/data/benign/benign (197).png
#   inflating: /kaggle/working/data/benign/benign (198).png
#   inflating: /kaggle/working/data/benign/benign (199).png
#   inflating: /kaggle/working/data/benign/benign (2).png
#   inflating: /kaggle/working/data/benign/benign (20).png
#   inflating: /kaggle/working/data/benign/benign (200).png
#   inflating: /kaggle/working/data/benign/benign (201).png
#   inflating: /kaggle/working/data/benign/benign (202).png
#   inflating: /kaggle/working/data/benign/benign (203).png
#   inflating: /kaggle/working/data/benign/benign (204).png
#   inflating: /kaggle/working/data/benign/benign (205).png
#   inflating: /kaggle/working/data/benign/benign (206).png
#   inflating: /kaggle/working/data/benign/benign (207).png
#   inflating: /kaggle/working/data/benign/benign (208).png
#   inflating: /kaggle/working/data/benign/benign (209).png
#   inflating: /kaggle/working/data/benign/benign (21).png
#   inflating: /kaggle/working/data/benign/benign (210).png
#   inflating: /kaggle/working/data/benign/benign (211).png
#   inflating: /kaggle/working/data/benign/benign (212).png
#   inflating: /kaggle/working/data/benign/benign (213).png
#   inflating: /kaggle/working/data/benign/benign (214).png
#   inflating: /kaggle/working/data/benign/benign (215).png
#   inflating: /kaggle/working/data/benign/benign (216).png
#   inflating: /kaggle/working/data/benign/benign (217).png
#   inflating: /kaggle/working/data/benign/benign (218).png
#   inflating: /kaggle/working/data/benign/benign (219).png
#   inflating: /kaggle/working/data/benign/benign (22).png
#   inflating: /kaggle/working/data/benign/benign (220).png
#   inflating: /kaggle/working/data/benign/benign (221).png
#   inflating: /kaggle/working/data/benign/benign (222).png
#   inflating: /kaggle/working/data/benign/benign (223).png
#   inflating: /kaggle/working/data/benign/benign (224).png
#   inflating: /kaggle/working/data/benign/benign (225).png
#   inflating: /kaggle/working/data/benign/benign (226).png
#   inflating: /kaggle/working/data/benign/benign (227).png
#   inflating: /kaggle/working/data/benign/benign (228).png
#   inflating: /kaggle/working/data/benign/benign (229).png
#   inflating: /kaggle/working/data/benign/benign (23).png
#   inflating: /kaggle/working/data/benign/benign (230).png
#   inflating: /kaggle/working/data/benign/benign (231).png
#   inflating: /kaggle/working/data/benign/benign (232).png
#   inflating: /kaggle/working/data/benign/benign (233).png
#   inflating: /kaggle/working/data/benign/benign (234).png
#   inflating: /kaggle/working/data/benign/benign (235).png
#   inflating: /kaggle/working/data/benign/benign (236).png
#   inflating: /kaggle/working/data/benign/benign (237).png
#   inflating: /kaggle/working/data/benign/benign (238).png
#   inflating: /kaggle/working/data/benign/benign (239).png
#   inflating: /kaggle/working/data/benign/benign (24).png
#   inflating: /kaggle/working/data/benign/benign (240).png
#   inflating: /kaggle/working/data/benign/benign (241).png
#   inflating: /kaggle/working/data/benign/benign (242).png
#   inflating: /kaggle/working/data/benign/benign (243).png
#   inflating: /kaggle/working/data/benign/benign (244).png
#   inflating: /kaggle/working/data/benign/benign (245).png
#   inflating: /kaggle/working/data/benign/benign (246).png
#   inflating: /kaggle/working/data/benign/benign (247).png
#   inflating: /kaggle/working/data/benign/benign (248).png
#   inflating: /kaggle/working/data/benign/benign (249).png
#   inflating: /kaggle/working/data/benign/benign (25).png
#   inflating: /kaggle/working/data/benign/benign (250).png
#   inflating: /kaggle/working/data/benign/benign (251).png
#   inflating: /kaggle/working/data/benign/benign (252).png
#   inflating: /kaggle/working/data/benign/benign (253).png
#   inflating: /kaggle/working/data/benign/benign (254).png
#   inflating: /kaggle/working/data/benign/benign (255).png
#   inflating: /kaggle/working/data/benign/benign (256).png
#   inflating: /kaggle/working/data/benign/benign (257).png
#   inflating: /kaggle/working/data/benign/benign (258).png
#   inflating: /kaggle/working/data/benign/benign (259).png
#   inflating: /kaggle/working/data/benign/benign (26).png
#   inflating: /kaggle/working/data/benign/benign (260).png
#   inflating: /kaggle/working/data/benign/benign (261).png
#   inflating: /kaggle/working/data/benign/benign (262).png
#   inflating: /kaggle/working/data/benign/benign (263).png
#   inflating: /kaggle/working/data/benign/benign (264).png
#   inflating: /kaggle/working/data/benign/benign (265).png
#   inflating: /kaggle/working/data/benign/benign (266).png
#   inflating: /kaggle/working/data/benign/benign (267).png
#   inflating: /kaggle/working/data/benign/benign (268).png
#   inflating: /kaggle/working/data/benign/benign (269).png
#   inflating: /kaggle/working/data/benign/benign (27).png
#   inflating: /kaggle/working/data/benign/benign (270).png
#   inflating: /kaggle/working/data/benign/benign (271).png
#   inflating: /kaggle/working/data/benign/benign (272).png
#   inflating: /kaggle/working/data/benign/benign (273).png
#   inflating: /kaggle/working/data/benign/benign (274).png
#   inflating: /kaggle/working/data/benign/benign (275).png
#   inflating: /kaggle/working/data/benign/benign (276).png
#   inflating: /kaggle/working/data/benign/benign (277).png
#   inflating: /kaggle/working/data/benign/benign (278).png
#   inflating: /kaggle/working/data/benign/benign (279).png
#   inflating: /kaggle/working/data/benign/benign (28).png
#   inflating: /kaggle/working/data/benign/benign (280).png
#   inflating: /kaggle/working/data/benign/benign (281).png
#   inflating: /kaggle/working/data/benign/benign (282).png
#   inflating: /kaggle/working/data/benign/benign (283).png
#   inflating: /kaggle/working/data/benign/benign (284).png
#   inflating: /kaggle/working/data/benign/benign (285).png
#   inflating: /kaggle/working/data/benign/benign (286).png
#   inflating: /kaggle/working/data/benign/benign (287).png
#   inflating: /kaggle/working/data/benign/benign (288).png
#   inflating: /kaggle/working/data/benign/benign (289).png
#   inflating: /kaggle/working/data/benign/benign (29).png
#   inflating: /kaggle/working/data/benign/benign (290).png
#   inflating: /kaggle/working/data/benign/benign (291).png
#   inflating: /kaggle/working/data/benign/benign (292).png
#   inflating: /kaggle/working/data/benign/benign (293).png
#   inflating: /kaggle/working/data/benign/benign (294).png
#   inflating: /kaggle/working/data/benign/benign (295).png
#   inflating: /kaggle/working/data/benign/benign (296).png
#   inflating: /kaggle/working/data/benign/benign (297).png
#   inflating: /kaggle/working/data/benign/benign (298).png
#   inflating: /kaggle/working/data/benign/benign (299).png
#   inflating: /kaggle/working/data/benign/benign (3).png
#   inflating: /kaggle/working/data/benign/benign (30).png
#   inflating: /kaggle/working/data/benign/benign (300).png
#   inflating: /kaggle/working/data/benign/benign (301).png
#   inflating: /kaggle/working/data/benign/benign (302).png
#   inflating: /kaggle/working/data/benign/benign (303).png
#   inflating: /kaggle/working/data/benign/benign (304).png
#   inflating: /kaggle/working/data/benign/benign (305).png
#   inflating: /kaggle/working/data/benign/benign (306).png
#   inflating: /kaggle/working/data/benign/benign (307).png
#   inflating: /kaggle/working/data/benign/benign (308).png
#   inflating: /kaggle/working/data/benign/benign (309).png
#   inflating: /kaggle/working/data/benign/benign (31).png
#   inflating: /kaggle/working/data/benign/benign (310).png
#   inflating: /kaggle/working/data/benign/benign (311).png
#   inflating: /kaggle/working/data/benign/benign (312).png
#   inflating: /kaggle/working/data/benign/benign (313).png
#   inflating: /kaggle/working/data/benign/benign (314).png
#   inflating: /kaggle/working/data/benign/benign (315).png
#   inflating: /kaggle/working/data/benign/benign (316).png
#   inflating: /kaggle/working/data/benign/benign (317).png
#   inflating: /kaggle/working/data/benign/benign (318).png
#   inflating: /kaggle/working/data/benign/benign (319).png
#   inflating: /kaggle/working/data/benign/benign (32).png
#   inflating: /kaggle/working/data/benign/benign (320).png
#   inflating: /kaggle/working/data/benign/benign (321).png
#   inflating: /kaggle/working/data/benign/benign (322).png
#   inflating: /kaggle/working/data/benign/benign (323).png
#   inflating: /kaggle/working/data/benign/benign (324).png
#   inflating: /kaggle/working/data/benign/benign (325).png
#   inflating: /kaggle/working/data/benign/benign (326).png
#   inflating: /kaggle/working/data/benign/benign (327).png
#   inflating: /kaggle/working/data/benign/benign (328).png
#   inflating: /kaggle/working/data/benign/benign (329).png
#   inflating: /kaggle/working/data/benign/benign (33).png
#   inflating: /kaggle/working/data/benign/benign (330).png
#   inflating: /kaggle/working/data/benign/benign (331).png
#   inflating: /kaggle/working/data/benign/benign (332).png
#   inflating: /kaggle/working/data/benign/benign (333).png
#   inflating: /kaggle/working/data/benign/benign (334).png
#   inflating: /kaggle/working/data/benign/benign (335).png
#   inflating: /kaggle/working/data/benign/benign (336).png
#   inflating: /kaggle/working/data/benign/benign (337).png
#   inflating: /kaggle/working/data/benign/benign (338).png
#   inflating: /kaggle/working/data/benign/benign (339).png
#   inflating: /kaggle/working/data/benign/benign (34).png
#   inflating: /kaggle/working/data/benign/benign (340).png
# ...
#   inflating: /kaggle/working/data/malignant_mask/desktop.ini
#   inflating: /kaggle/working/data/malignant_mask/malignant (1)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (10)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (100)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (101)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (102)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (103)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (104)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (105)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (106)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (107)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (108)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (109)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (11)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (110)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (111)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (112)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (113)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (114)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (115)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (116)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (117)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (118)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (119)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (12)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (120)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (121)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (122)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (123)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (124)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (125)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (126)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (127)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (128)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (129)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (13)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (130)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (131)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (132)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (133)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (134)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (135)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (136)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (137)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (138)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (139)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (14)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (140)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (141)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (142)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (143)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (144)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (145)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (146)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (147)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (148)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (149)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (15)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (150)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (151)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (152)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (153)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (154)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (155)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (156)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (157)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (158)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (159)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (16)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (160)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (161)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (162)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (163)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (164)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (165)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (166)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (167)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (168)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (169)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (17)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (170)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (171)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (172)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (173)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (174)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (175)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (176)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (177)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (178)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (179)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (18)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (180)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (181)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (182)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (183)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (184)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (185)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (186)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (187)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (188)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (189)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (19)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (190)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (191)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (192)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (193)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (194)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (195)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (196)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (197)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (198)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (199)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (2)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (20)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (200)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (201)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (202)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (203)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (204)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (205)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (206)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (207)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (208)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (209)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (21)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (210)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (22)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (23)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (24)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (25)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (26)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (27)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (28)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (29)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (3)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (30)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (31)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (32)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (33)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (34)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (35)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (36)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (37)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (38)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (39)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (4)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (40)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (41)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (42)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (43)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (44)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (45)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (46)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (47)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (48)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (49)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (5)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (50)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (51)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (52)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (53)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (53)_mask_1.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (54)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (55)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (56)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (57)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (58)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (59)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (6)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (60)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (61)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (62)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (63)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (64)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (65)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (66)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (67)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (68)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (69)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (7)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (70)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (71)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (72)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (73)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (74)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (75)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (76)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (77)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (78)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (79)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (8)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (80)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (81)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (82)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (83)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (84)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (85)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (86)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (87)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (88)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (89)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (9)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (90)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (91)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (92)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (93)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (94)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (95)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (96)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (97)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (98)_mask.png
#   inflating: /kaggle/working/data/malignant_mask/malignant (99)_mask.png

# %%
base_path = '/kaggle/working/data'

for folder in os.listdir(base_path):
    full_path = os.path.join(base_path, folder)
    
    if os.path.isdir(full_path):
        num_files = len(os.listdir(full_path))
        print(f'{folder}: {num_files} files')
# Out:
# malignant_mask: 212 files
# malignant: 210 files
# benign: 437 files
# benign_mask: 455 files

# %%
# Make sure to get the right image file
def extract_idx(filename):
  """
  Extract index from the filename
  """
  index = re.search(r'\((\d+)\)', filename)
  if index is not None:
    return int(index.group(1))
  else: return -1

def is_valid_image(filename, prefix, is_mask=False):
  """
  Make sure the file and the pattern in the dataset match in order to avoid duplicate images
  """
  if is_mask:
    pattern = rf'{prefix} \(\d+\)_mask\.png$'
  else:
      pattern = rf'{prefix} \(\d+\)\.png$'
  return re.match(pattern, filename)

# %%
"""
  Clean up the images directories
  read all images in the directory -> extract only images by index in the file -> validate to remove duplicate or invalid image
  sort them based on the index
"""
benign = sorted(
    [f for f in os.listdir(f'{base_path}/benign') if extract_idx(f) != -1 and is_valid_image(f, 'benign', False)],
    key=extract_idx)
benign_mask = sorted(
    [f for f in os.listdir(f'{base_path}/benign_mask') if extract_idx(f) != -1 and is_valid_image(f, 'benign', True)],
    key=extract_idx)
malignant = sorted(
    [f for f in os.listdir(f'{base_path}/malignant') if extract_idx(f) != -1 and is_valid_image(f, 'malignant', False)],
    key=extract_idx)
malignant_mask = sorted(
    [f for f in os.listdir(f'{base_path}/malignant_mask') if extract_idx(f) != -1 and is_valid_image(f, 'malignant', True)],
    key=extract_idx)

# %%
len(benign), len(benign_mask), len(malignant), len(malignant_mask)
# Out:
# (437, 437, 210, 210)

# %%
# plot a random image from each classes
def plot_img_with_mask(depth, root):
  idx = np.random.randint(0, depth)
  fig, ax = plt.subplots(1, 5, figsize=(15, 4))

  # orignal image
  org_img = pltimg.imread(f'{base_path}/{root}/{root} ({idx}).png')
  # mask image
  mask_img = pltimg.imread(f'{base_path}/{root}_mask/{root} ({idx})_mask.png')

  # plot orinal img
  ax[0].imshow(org_img)
  ax[0].set_title(f"Orignal {root} ({idx})")
  ax[0].set_xticks([])
  ax[0].set_yticks([])

  # plot the mask img
  ax[1].imshow(mask_img)
  ax[1].set_title(f"Mask {root} ({idx})")
  ax[1].set_xticks([])
  ax[1].set_yticks([])


  print(f'maks_img shape: {mask_img.shape}')

  # add threshold for the mask image
  if len(mask_img.shape) == 3: # <-- if the image is not already in 1 chanel(gray scale)
    imgray = cv2.cvtColor(mask_img, cv2.COLOR_BGR2GRAY)
  else:
    imgray = mask_img

  imgray = (imgray * 255).astype("uint8") # <-- change image type
  _, threshold = cv2.threshold(imgray, 127, 255, cv2.THRESH_BINARY)
  contours, hierarchy = cv2.findContours(threshold,  cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

  # plot the contours image
  contours_img = cv2.drawContours(mask_img, contours, -1, (127,255,0), 2)
  ax[2].imshow(contours_img)
  ax[2].set_title(f"Contours {root} ({idx})")
  ax[2].set_xticks([])
  ax[2].set_yticks([])

  # masked the original image
  controus_img = org_img.copy()
  contours_org_img = cv2.drawContours(controus_img, contours, -1, (127, 255, 0), 2)
  ax[3].imshow(contours_org_img)
  ax[3].set_title(f'Masked {root} ({idx})', color='red')
  ax[3].set_xticks([])
  ax[3].set_yticks([])

  # Contours bounding box
  bound_img = org_img.copy()
  for cnt in contours:
    x, y, w, h = cv2.boundingRect(cnt)
    cv2.rectangle(bound_img, (x, y), (x+w, y+h), (0, 255, 0, 0), 4)
  ax[4].imshow(bound_img)
  ax[4].set_title(f'Bounding Contours {root} ({idx})', color='red')
  ax[4].set_xticks([])
  ax[4].set_yticks([])

  plt.tight_layout()

# %%
plot_img_with_mask(len(benign), f'benign')
plot_img_with_mask(len(malignant), f'malignant')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# maks_img shape: (587, 775)
# maks_img shape: (339, 233)

# %%
# add threshold for the mask image
# orignal image
org_img = pltimg.imread(f'{base_path}/benign/benign (15).png')
# mask image
mask_img = pltimg.imread(f'{base_path}/benign_mask/benign (15)_mask.png')

if len(mask_img.shape) == 3: # <-- if the image is not already in 1 chanel(gray scale)
  imgray = cv2.cvtColor(mask_img, cv2.COLOR_BGR2GRAY)
else:
  imgray = mask_img

imgray = (imgray * 255).astype("uint8") # <-- change image type
_, threshold = cv2.threshold(imgray, 127, 255, cv2.THRESH_BINARY)
contours, hierarchy = cv2.findContours(threshold,  cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

contours_org_img = cv2.drawContours(org_img, contours, -1, (127, 255, 0), 2)
for cnt in contours:
  x, y, w, h = cv2.boundingRect(cnt)
  print(x, y, w, h)
  cv2.rectangle(contours_org_img, (x, y), (x + w, y + h), (0, 255, 0), 2)

plt.imshow(contours_org_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# 227 128 67 62

# %%
# Get the mean and std of feature images
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # keep consistent size
    transforms.ToTensor()
])

class FilteredImageFolder(torchvision.datasets.ImageFolder):
    def find_classes(self, directory):
        classes = ['benign', 'malignant']  # only features, not attributes
        class_to_idx = {cls: i for i, cls in enumerate(classes)}
        return classes, class_to_idx

dataset = FilteredImageFolder(base_path, transform=transform)

loader = torch.utils.data.DataLoader(dataset, batch_size=32, shuffle=False, num_workers=2)

mean = 0.
std = 0.
total_images = 0

for images, _ in loader:
    batch_size = images.size(0)
    images = images.view(batch_size, images.size(1), -1)  # flatten H,W
    
    mean += images.mean(2).sum(0)
    std += images.std(2).sum(0)
    
    total_images += batch_size

mean /= total_images
std /= total_images

print("Mean:", mean)
print("Std:", std)
# Out:
# Mean: tensor([0.3301, 0.3301, 0.3300])
# Std: tensor([0.2016, 0.2016, 0.2016])

# %%
# Denormalize method for displying normalized image
# g_mean = [0.485, 0.456, 0.406]
# g_std = [0.229, 0.224, 0.225]
g_mean = [0.3301, 0.3301, 0.3300]
g_std = [0.2016, 0.2016, 0.2016]
def denormalize(img):
    if isinstance(img, torch.Tensor):
        mean = torch.tensor(g_mean, device=img.device)
        std = torch.tensor(g_std, device=img.device)
        return img * std[:, None, None] + mean[:, None, None]

    elif isinstance(img, np.ndarray):
        mean = np.array(g_mean)
        std = np.array(g_std)
        return img * std[None, None, :] + mean[None, None, :]

# %%
# Providing the mask get the boundry box
def get_bbox_and_cnt(mask):
  if len(mask.shape) == 3:
    imgray = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
  else:
    imgray = mask

  imgray = (imgray * 255).astype("uint8") # <-- change image type
  _, threshold = cv2.threshold(imgray, 127, 255, cv2.THRESH_BINARY)

  # get the contours
  contours, _ = cv2.findContours(threshold,  cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
  if len(contours)==0:
    return None

  # take the largest contour
  cnt = max(contours, key=cv2.contourArea)
  # get the bounding box
  x, y, w, h = cv2.boundingRect(cnt)

  return contours, [x, y, w, h]

# %%
# splitting the Benign to training and testing
def split_dataset(data):
  train_size = int(0.7 * len(data)) # 70%
  valid_size = int(0.2 * len(data)) # 20%
  test_size = len(data) - train_size - valid_size # 10%
  generator = torch.Generator().manual_seed(0)
  train, val, test = torch.utils.data.random_split(data, [train_size, valid_size, test_size], generator=generator)
  return train, val, test

# %%
class Dataset(torch.utils.data.Dataset):
  def __init__(self, img_list, mask_list, img_dir, mask_dir, transform=None, image_size=None):
    self.img_list = img_list
    self.mask_list = mask_list
    self.img_dir = img_dir
    self.mask_dir = mask_dir
    self.transform = transform
    self.image_size = image_size

  def __len__(self):
    return len(self.img_list)

  def __getitem__(self, index):
    image_path = os.path.join(self.img_dir, self.img_list[index])
    mask_path = os.path.join(self.mask_dir, self.mask_list[index])

    image = Image.open(image_path).convert("RGB")
    mask = Image.open(mask_path)

    image = np.array(image)
    mask = np.array(mask)

    _, bbox = get_bbox_and_cnt(mask)
    if bbox is None:
      bbox = [0, 0, 0, 0]
    if self.transform:
      result = self.transform(image=image, bboxes=[bbox])
      image = result['image']
      bbox = result['bboxes'][0]

    bbox = np.array(bbox)/self.image_size

    return image.float(), torch.tensor(bbox, dtype=torch.float32)

# %%
# Create a Augmentation Pipeline
img_size = 512
train_transform_pipeline = A.Compose([
    A.Resize(img_size, img_size),

    # Geometric
    # A.HorizontalFlip(p=0.2),

    A.ShiftScaleRotate(
        shift_limit=0.05,
        scale_limit=0.1,
        rotate_limit=15,
        p=0.1
    ),

    # A.ElasticTransform(alpha=1, sigma=50, p=0.2), # Simulates tissue deformation
    # A.GridDistortion(p=0.2),

    # Light intensity changes
    A.RandomBrightnessContrast(p=0.1),
    A.GaussNoise(std_range=(0.1, 0.5), p=0.1),

    A.GaussianBlur(
         sigma_limit=(0.2, 0.5),  # Small sigma for subtle blur
         blur_limit=0,            # Auto-compute kernel size
         p=0.2
     ),

    A.Normalize(mean=g_mean, std=g_std ),
    A.pytorch.ToTensorV2(),
],
bbox_params=A.BboxParams(format='coco', min_visibility=0.3, label_fields=[]))
validation_transform_pipeline = A.Compose([
    A.Resize(img_size, img_size),
    A.Normalize(mean=g_mean, std=g_std ),
    A.pytorch.ToTensorV2(),
],
bbox_params=A.BboxParams(format='coco', min_visibility=0.3, label_fields=[]))
# Out:
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)

# %%
# Get all the benign dataset
ben_train_data, ben_val_data, ben_test_data = split_dataset(benign)
ben_train_mask, ben_val_mask, ben_test_mask = split_dataset(benign_mask)
benign_train = Dataset(ben_train_data, ben_train_mask, f'{base_path}/benign', f'{base_path}/benign_mask', transform=train_transform_pipeline, image_size=img_size)
benign_val = Dataset(ben_val_data, ben_val_mask, f'{base_path}/benign', f'{base_path}/benign_mask', transform=validation_transform_pipeline, image_size=img_size)
benign_test = Dataset(ben_test_data, ben_test_mask, f'{base_path}/benign', f'{base_path}/benign_mask', transform=validation_transform_pipeline, image_size=img_size)

# %%
# Get all the malignant dataset
mal_train_data, mal_val_data, mal_test_data = split_dataset(malignant)
mal_train_mask, mal_val_mask, mal_test_mask = split_dataset(malignant_mask)
malignant_train = Dataset(mal_train_data, mal_train_mask, f'{base_path}/malignant', f'{base_path}/malignant_mask', transform=train_transform_pipeline, image_size=img_size)
malignant_val = Dataset(mal_val_data, mal_val_mask, f'{base_path}/malignant', f'{base_path}/malignant_mask', transform=validation_transform_pipeline, image_size=img_size)
malignant_test = Dataset(mal_test_data, mal_test_mask, f'{base_path}/malignant', f'{base_path}/malignant_mask', transform=validation_transform_pipeline, image_size=img_size)

# %%
img, label = malignant_train.__getitem__(1)
img.shape, label.shape
# Out:
# (torch.Size([3, 512, 512]), torch.Size([4]))

# %%
# plot some augmented images
plt.figure(figsize=(15, 7))
for i in range(8):
  if i<4:
    idx = np.random.randint(0, len(benign_train))

    img, box = benign_train.__getitem__(idx)
  else:
    idx = np.random.randint(0, len(malignant_train))

    img, box = malignant_train.__getitem__(idx)

  img = img.permute(1,2,0).cpu().numpy()
  h_img, w_img, _ = img.shape

  x, y, w, h = box

  # 1. convert to pixel space
  x = x.item() * w_img
  y = y.item() * h_img
  w = w.item() * w_img
  h = h.item() * h_img

  # 2. fix negatives
  x = max(0, int(x))
  y = max(0, int(y))
  w = max(1, int(w))
  h = max(1, int(h))

  plt.subplot(2, 4, i+1)
  denorm_img = denormalize(img)
  bound_img = cv2.rectangle(denorm_img.copy(),
                            (x, y),
                            (x+w, y+h),
                            (255, 0, 0),
                            2)
  plt.imshow(bound_img)
  plt.title(f"image {idx}")
plt.tight_layout()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].

# %%
len(benign_train), len(benign_val), len(benign_test), len(malignant_train), len(malignant_val), len(malignant_test)
# Out:
# (305, 87, 45, 147, 42, 21)

# %%
# combining the Benign & Malignant datasets
train_data = torch.utils.data.ConcatDataset([benign_train, malignant_train])
val_data = torch.utils.data.ConcatDataset([benign_val, malignant_val])
test_data = torch.utils.data.ConcatDataset([benign_test, malignant_test])

# %%
len(train_data), len(val_data), len(test_data)
# Out:
# (452, 129, 66)

# %%
start_time = time()
train_dir = f"{base_path}/dataset/train"
val_dir = f"{base_path}/dataset/val"
# create directory if it doesn't exist
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)
for i in range(len(train_data)):
    tr_image, tr_label = train_data[i]   # <-- NOW data is loaded
    torch.save((tr_image, tr_label), f"{train_dir}/tr_{i}.pt")

for i in range(len(val_data)):
    val_image, val_label = val_data[i]
    torch.save((val_image, val_label), f"{val_dir}/val_{i}.pt")
print(f'tokes {time()-start_time}s')
# Out:
# tokes 10.464739561080933s

# %%
class CachedDataset(torch.utils.data.Dataset):
    def __init__(self, data_dir):
        self.files = os.listdir(data_dir)
        self.data_dir = data_dir

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        path = os.path.join(self.data_dir, self.files[idx])
        image, bbox = torch.load(path, weights_only=False)
        return image, bbox

# %%
train_dataset = CachedDataset(train_dir)
val_dataset = CachedDataset(val_dir)
len(train_dataset), len(val_dataset)
# Out:
# (452, 129)

# %%
# add data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=32, num_workers=2, shuffle=True, drop_last=True)
valid_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=32, num_workers=2, shuffle=True)
len(train_loader.dataset), len(valid_loader.dataset)
# Out:
# (452, 129)

# %%
# plot some augmented images with bbox
plt.figure(figsize=(15, 7))
for i in range(8):
  idx = np.random.randint(0, len(train_loader.dataset))
  img, box = train_loader.dataset.__getitem__(idx)

  img = img.permute(1,2,0).cpu().numpy()
  h_img, w_img, _ = img.shape

  x, y, w, h = box

  # 1. convert to pixel space
  x = x.item() * w_img
  y = y.item() * h_img
  w = w.item() * w_img
  h = h.item() * h_img

  # 2. fix negatives
  x = max(0, int(x))
  y = max(0, int(y))
  w = max(1, int(w))
  h = max(1, int(h))

  plt.subplot(2, 4, i+1)
  denorm_img = denormalize(img)
  bound_img = cv2.rectangle(denorm_img.copy(),
                            (x, y),
                            (x+w, y+h),
                            (255, 0, 0),
                            2)
  plt.imshow(bound_img)
  plt.title(f"image {idx}")
plt.tight_layout()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].

# %%
# create Residual with skip connection support
class ResidualBlock(nn.Module):
    def __init__(self, in_c, out_c, stride=1):
        super().__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(in_c, out_c, 3, padding=1, stride=stride),
            nn.BatchNorm2d(out_c),
            nn.ReLU(),

            nn.Conv2d(out_c, out_c, 3, padding=1),
            nn.BatchNorm2d(out_c)
        )

        # match dimensions for skip connection
        if in_c != out_c or stride != 1:
            self.skip = nn.Sequential(
                nn.Conv2d(in_c, out_c, kernel_size=1, stride=stride),
                nn.BatchNorm2d(out_c)
            )
        else:
            self.skip = nn.Identity()

        self.relu = nn.ReLU()

    def forward(self, x):
        residual = self.skip(x)      # original path

        out = self.conv(x)           # transformed path

        out = out + residual
        out = self.relu(out)  #  RESIDUAL ADDED

        return out

# %%
# Builing the network
class Cnn_network(nn.Module):
  def __init__(self):
    super(Cnn_network, self).__init__()

    # Encoder
    self.block1 = nn.Sequential(
        ResidualBlock(3, 32, stride=2),
        ResidualBlock(32, 32, stride=1)
    )

    self.block2 = nn.Sequential(
        ResidualBlock(32, 64, stride=2),
        ResidualBlock(64, 64, stride=1)
    )

    self.block3 = nn.Sequential(
        ResidualBlock(64, 128, stride=2),
        ResidualBlock(128, 128, stride=1)
    )

    self.block4 = nn.Sequential(
        ResidualBlock(128, 256, stride=2),
        ResidualBlock(256, 256, stride=1)
    )

    # self.dropout = nn.Dropout2d(0.1)
    self.fuse_head = nn.Sequential(
        nn.Conv2d(256 + 128, 256, 1),
        nn.ReLU()
    )

    self.head = nn.Sequential(
        nn.Conv2d(256, 256, 3, padding=1),
        nn.ReLU(),

        nn.Conv2d(256, 128, 3, padding=1),
        nn.ReLU(),

        nn.Conv2d(128, 64, 3, padding=1),
        nn.ReLU(),

        nn.Conv2d(64, 5, 1), # objectness = probability that a box actually contains an object

    )
    self.attention_head = nn.Conv2d(256, 5, 1)

  def forward(self, x):

    # Encoder
    x1 = self.block1(x)
    x2 = self.block2(x1)
    x3 = self.block3(x2)
    x4 = self.block4(x3) # <-- Bottleneck
    # x4 = self.dropout(x4) # <-- reduce noise at bottleneck

    # -------------------------
    # 🔥 FEATURE FUSION
    # -------------------------

    x4_up = nn.functional.interpolate(x4, size=x3.shape[2:])

    # combine deep + mid features
    fused = torch.cat([x3, x4_up], dim=1)

    fused = self.fuse_head(fused)

    # -------------------------
    # HEAD (bbox prediction)
    # -------------------------

    # output objects
    features = self.head(fused)
    attention_logits = self.attention_head(fused)  # [B, 5, H, W]

    B, C, H, W = attention_logits.shape

    # flatten spatial dims
    attention = attention_logits.view(B, C, -1)
    # apply softmax over spatial locations
    attention = torch.softmax(attention, dim=2)
    # reshape back
    attention = attention.view(B, C, H, W)
      
    weighted = features * attention # Let network learn where to look
    out = weighted.sum(dim=(2,3))   
    return out
net = Cnn_network().to(device)
summary(net, input_size=(3, 512, 512))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 256, 256]             128
#        BatchNorm2d-2         [-1, 32, 256, 256]              64
#             Conv2d-3         [-1, 32, 256, 256]             896
#        BatchNorm2d-4         [-1, 32, 256, 256]              64
#               ReLU-5         [-1, 32, 256, 256]               0
#             Conv2d-6         [-1, 32, 256, 256]           9,248
#        BatchNorm2d-7         [-1, 32, 256, 256]              64
#               ReLU-8         [-1, 32, 256, 256]               0
#      ResidualBlock-9         [-1, 32, 256, 256]               0
#          Identity-10         [-1, 32, 256, 256]               0
#            Conv2d-11         [-1, 32, 256, 256]           9,248
#       BatchNorm2d-12         [-1, 32, 256, 256]              64
#              ReLU-13         [-1, 32, 256, 256]               0
#            Conv2d-14         [-1, 32, 256, 256]           9,248
#       BatchNorm2d-15         [-1, 32, 256, 256]              64
#              ReLU-16         [-1, 32, 256, 256]               0
#     ResidualBlock-17         [-1, 32, 256, 256]               0
#            Conv2d-18         [-1, 64, 128, 128]           2,112
#       BatchNorm2d-19         [-1, 64, 128, 128]             128
#            Conv2d-20         [-1, 64, 128, 128]          18,496
#       BatchNorm2d-21         [-1, 64, 128, 128]             128
#              ReLU-22         [-1, 64, 128, 128]               0
#            Conv2d-23         [-1, 64, 128, 128]          36,928
#       BatchNorm2d-24         [-1, 64, 128, 128]             128
#              ReLU-25         [-1, 64, 128, 128]               0
#     ResidualBlock-26         [-1, 64, 128, 128]               0
#          Identity-27         [-1, 64, 128, 128]               0
#            Conv2d-28         [-1, 64, 128, 128]          36,928
#       BatchNorm2d-29         [-1, 64, 128, 128]             128
#              ReLU-30         [-1, 64, 128, 128]               0
#            Conv2d-31         [-1, 64, 128, 128]          36,928
#       BatchNorm2d-32         [-1, 64, 128, 128]             128
#              ReLU-33         [-1, 64, 128, 128]               0
#     ResidualBlock-34         [-1, 64, 128, 128]               0
#            Conv2d-35          [-1, 128, 64, 64]           8,320
#       BatchNorm2d-36          [-1, 128, 64, 64]             256
#            Conv2d-37          [-1, 128, 64, 64]          73,856
#       BatchNorm2d-38          [-1, 128, 64, 64]             256
#              ReLU-39          [-1, 128, 64, 64]               0
#            Conv2d-40          [-1, 128, 64, 64]         147,584
#       BatchNorm2d-41          [-1, 128, 64, 64]             256
#              ReLU-42          [-1, 128, 64, 64]               0
#     ResidualBlock-43          [-1, 128, 64, 64]               0
#          Identity-44          [-1, 128, 64, 64]               0
#            Conv2d-45          [-1, 128, 64, 64]         147,584
#       BatchNorm2d-46          [-1, 128, 64, 64]             256
#              ReLU-47          [-1, 128, 64, 64]               0
#            Conv2d-48          [-1, 128, 64, 64]         147,584
#       BatchNorm2d-49          [-1, 128, 64, 64]             256
#              ReLU-50          [-1, 128, 64, 64]               0
#     ResidualBlock-51          [-1, 128, 64, 64]               0
#            Conv2d-52          [-1, 256, 32, 32]          33,024
#       BatchNorm2d-53          [-1, 256, 32, 32]             512
#            Conv2d-54          [-1, 256, 32, 32]         295,168
#       BatchNorm2d-55          [-1, 256, 32, 32]             512
#              ReLU-56          [-1, 256, 32, 32]               0
#            Conv2d-57          [-1, 256, 32, 32]         590,080
#       BatchNorm2d-58          [-1, 256, 32, 32]             512
#              ReLU-59          [-1, 256, 32, 32]               0
#     ResidualBlock-60          [-1, 256, 32, 32]               0
#          Identity-61          [-1, 256, 32, 32]               0
#            Conv2d-62          [-1, 256, 32, 32]         590,080
#       BatchNorm2d-63          [-1, 256, 32, 32]             512
#              ReLU-64          [-1, 256, 32, 32]               0
#            Conv2d-65          [-1, 256, 32, 32]         590,080
#       BatchNorm2d-66          [-1, 256, 32, 32]             512
#              ReLU-67          [-1, 256, 32, 32]               0
#     ResidualBlock-68          [-1, 256, 32, 32]               0
#            Conv2d-69          [-1, 256, 64, 64]          98,560
#              ReLU-70          [-1, 256, 64, 64]               0
#            Conv2d-71          [-1, 256, 64, 64]         590,080
#              ReLU-72          [-1, 256, 64, 64]               0
#            Conv2d-73          [-1, 128, 64, 64]         295,040
#              ReLU-74          [-1, 128, 64, 64]               0
#            Conv2d-75           [-1, 64, 64, 64]          73,792
#              ReLU-76           [-1, 64, 64, 64]               0
#            Conv2d-77            [-1, 5, 64, 64]             325
#            Conv2d-78            [-1, 5, 64, 64]           1,285
# ================================================================
# Total params: 3,847,402
# Trainable params: 3,847,402
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 3.00
# Forward/backward pass size (MB): 554.31
# Params size (MB): 14.68
# Estimated Total Size (MB): 571.99
# ----------------------------------------------------------------

# %%
# test the model
dumy_dataset = torch.randn(1, 3, 300, 300).to(device)
# test the model
pred = net(dumy_dataset)
pred
# Out:
# tensor([[-0.0729,  0.1153, -0.0187, -0.0617,  0.1032]], device='cuda:0',
#        grad_fn=<SumBackward1>)

# %%
# define the compiler
optimizer = torch.optim.AdamW(params=net.parameters(), lr=0.000005, weight_decay=0.00001)
# ↑ (Adam with Weight Decay) decouples these, leading to better generalization more consistant decay

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, # Drops the learning rate when the validation loss stops improving
                                                       mode='min',
                                                       patience=2,
                                                       factor=0.5)

smooth_l1= nn.SmoothL1Loss(reduction="mean")
BCE = nn.BCEWithLogitsLoss() 
def loss_fun(y_pred, y, obj_pred):
    target_obj = torch.ones_like(obj_pred)
    loss = smooth_l1(y_pred, y) + 0.5 * BCE(obj_pred, target_obj)
    return loss

# %%
# training method
def train(data_loader, loss_fun, optimizer):
  # print(f'is training: {net.training}')
  size = len(data_loader.dataset)
  training_loss = 0
  number_of_batches = len(data_loader)

  net.train(mode=True) # set the model in the training mode
  for batch, (X, y) in enumerate(data_loader):
    X, y = X.to(device), y.to(device)

    # y = y.unsqueeze(1).float()
    # reset all the gradient
    optimizer.zero_grad()

    pred = net(X) # <-- directly calling the forward method
    bbox_pred = pred[:, :4]
    obj_pred  = pred[:, 4]

    loss = loss_fun(bbox_pred, y, obj_pred)

    loss.backward() # compute the gradient
    # at this point we computed the gradient
    torch.nn.utils.clip_grad_norm_(net.parameters(), 1.0) # <-- Since my dataset is very small
    optimizer.step() # update the weights
    training_loss += loss.item()
    if (batch+1 == number_of_batches):
      print(f'Batch {batch+1}/{number_of_batches} | Loss: {loss.item():.4f}')

  return training_loss/number_of_batches

# %%
# Validate the model
def val_model(data_loader, loss_fun):
  val_loss = 0
  net.eval()
  with torch.no_grad(): # disable the grade calculation
    for data in data_loader:
      X, y = data
      X, y = X.to(device), y.to(device)
      # y = y.unsqueeze(1).float()

      pred = net(X) # <-- directly calling the forward method
      bbox_pred = pred[:, :4]
      obj_pred  = pred[:, 4]

      loss = loss_fun(bbox_pred, y, obj_pred)
        
      val_loss += loss.item()
  return val_loss/len(data_loader)

# %%
img, label = train_loader.dataset.__getitem__(0)
img.shape
# Out:
# torch.Size([3, 512, 512])

# %%
epoch = 15
history = {'tr_loss': [], 'val_loss': []}
best_val = float('inf')
patience = 5
counter = 0
best_epoch = 0
for i in range(epoch):
  print(f"Epoch {i}: ")
  tr_loss = train(train_loader, loss_fun, optimizer)
  history['tr_loss'].append(tr_loss)
  avg_loss = val_model(valid_loader, loss_fun)

  # update the learning rate
  scheduler.step(round(avg_loss, 4)) # <-- reduces noise sensitivity
  history['val_loss'].append(avg_loss)
  print(f"Validation loss: {avg_loss}")

  if avg_loss < best_val:
      best_val = avg_loss
      counter = 0
      best_epoch = i
      torch.save(net.state_dict(), "best_model.pth")
  else:
      counter += 1

  if counter >= patience:
      print("Early stopping!")
      break
print(f"Best model at epoch {best_epoch}")
# Out:
# Epoch 0:
# Batch 14/14 | Loss: 0.3759
# Validation loss: 0.38586260080337526
# Epoch 1:
# Batch 14/14 | Loss: 0.3581
# Validation loss: 0.36623708009719846
# Epoch 2:
# Batch 14/14 | Loss: 0.3187
# Validation loss: 0.3341403007507324
# Epoch 3:
# Batch 14/14 | Loss: 0.2607
# Validation loss: 0.26370262503623965
# Epoch 4:
# Batch 14/14 | Loss: 0.1709
# Validation loss: 0.13701001852750777
# Epoch 5:
# Batch 14/14 | Loss: 0.0858
# Validation loss: 0.07180158421397209
# Epoch 6:
# Batch 14/14 | Loss: 0.0567
# Validation loss: 0.040209687873721124
# Epoch 7:
# Batch 14/14 | Loss: 0.0369
# Validation loss: 0.04329053685069084
# Epoch 8:
# Batch 14/14 | Loss: 0.0336
# Validation loss: 0.030940423533320428
# Epoch 9:
# Batch 14/14 | Loss: 0.0259
# Validation loss: 0.026595737785100937
# Epoch 10:
# Batch 14/14 | Loss: 0.0185
# Validation loss: 0.021137783676385878
# Epoch 11:
# Batch 14/14 | Loss: 0.0189
# Validation loss: 0.019768332317471504
# Epoch 12:
# Batch 14/14 | Loss: 0.0216
# Validation loss: 0.016750027239322663
# Epoch 13:
# Batch 14/14 | Loss: 0.0189
# Validation loss: 0.02487866412848234
# Epoch 14:
# Batch 14/14 | Loss: 0.0170
# Validation loss: 0.01764206737279892
# Best model at epoch 12

# %%
# Plot the loss curve after adding atention head
pd.DataFrame(history).plot()
# Out:
# <Axes: >

# %%
# Plot the loss curve before adding atention head
pd.DataFrame(history).plot()
# Out:
# <Axes: >

# %%
model_path = f'{base_path}/bbox_m5.pt'

# %%
# save the model
torch.save(net.state_dict(), model_path)

# %%
# load the model
model = Cnn_network().to(device)

state_dict = torch.load(model_path, weights_only=True, map_location=torch.device('cpu'))
model.load_state_dict(state_dict)

model.eval()
# Out:
# Cnn_network(
#   (block1): Sequential(
#     (0): ResidualBlock(
#       (conv): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (skip): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU()
#     )
#     (1): ResidualBlock(
#       (conv): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (skip): Identity()
#       (relu): ReLU()
#     )
#   )
#   (block2): Sequential(
#     (0): ResidualBlock(
#       (conv): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (skip): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU()
#     )
#     (1): ResidualBlock(
#       (conv): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (skip): Identity()
#       (relu): ReLU()
#     )
#   )
#   (block3): Sequential(
#     (0): ResidualBlock(
#       (conv): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (skip): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU()
#     )
#     (1): ResidualBlock(
#       (conv): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (skip): Identity()
#       (relu): ReLU()
#     )
#   )
#   (block4): Sequential(
#     (0): ResidualBlock(
#       (conv): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (skip): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU()
#     )
#     (1): ResidualBlock(
#       (conv): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (skip): Identity()
#       (relu): ReLU()
#     )
#   )
#   (fuse_head): Sequential(
#     (0): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU()
#   )
#   (head): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(64, 5, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (attention_head): Conv2d(256, 5, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
test_data = torch.utils.data.ConcatDataset([benign_test, malignant_test])
test_loader = torch.utils.data.DataLoader(dataset=test_data, batch_size=32, num_workers=2, shuffle=True)

# %%
plt.figure(figsize=(15, 7))
for i in range(8):
  idx = np.random.randint(len(test_loader.dataset))
  img, bbox = test_loader.dataset[idx]
  pred_test = model(img.unsqueeze(0).to(device))

  img = img.permute(1,2,0).cpu().numpy()
  h_img, w_img, _ = img.shape

    # bbox_pred = pred[:, :4]
    # obj_pred  = pred[:, 4]
  x, y, w, h, obj_prob = pred_test[0].detach().cpu()

  # 1. convert to pixel space
  x = x.item() * w_img
  y = y.item() * h_img
  w = w.item() * w_img
  h = h.item() * h_img

  # 2. fix negatives
  x = max(0, int(x))
  y = max(0, int(y))
  w = max(1, int(w))
  h = max(1, int(h))

  # ground truth
  tx, ty, tw, th = bbox
  tx = tx.item()* w_img
  ty = ty.item()* h_img
  tw = tw.item()* w_img
  th = th.item()* h_img
  tx, ty, tw, th = map(int, [tx, ty, tw, th])

  img_copy = denormalize(img.copy())

  # draw predicted (green)
  cv2.rectangle(img_copy, (x, y), (x+w, y+h), (0, 255, 0), 2)

  # draw ground truth (red)
  cv2.rectangle(img_copy, (tx, ty), (tx+tw, ty+th), (255, 0, 0), 2)


  cv2.putText(img_copy, "Pred", (x, y-6),
              cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,255,0), 1)

  cv2.putText(img_copy, "GT", (tx, ty-6),
              cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255,0,0), 1)
  plt.subplot(2, 4, i+1)
  plt.imshow(img_copy)
  plt.title(f'Image {idx} - ({obj_prob:.3f})')
  plt.axis("off")
plt.tight_layout()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4877319320927285e-08..255.0].
