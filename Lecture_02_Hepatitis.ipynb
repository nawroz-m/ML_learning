# %% [markdown]
# <a href="https://colab.research.google.com/github/nawroz-m/ML_learning/blob/BigImgSingnal/Lecture_02_Hepatitis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import files, drive
import pandas as pd
import sklearn.ensemble
import sklearn.metrics
from sklearn.model_selection import train_test_split
import numpy as np

# %% [markdown]
# # 1 Load and explore the dataset

# %%
# Load file
drive.flush_and_unmount()
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Big Img Sig/hepatitis.csv")

# %%
df.head(5)
# Out:
#    age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0   30    male   False       False   False   False    False     False
# 1   50  female   False       False    True   False    False     False
# 2   78  female    True       False    True   False    False      True
# 3   31  female     NaN        True   False   False    False      True
# 4   34  female    True       False   False   False    False      True
#
#   liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# 0      False           False   False   False   False        1.0
# 1      False           False   False   False   False        0.9
# 2      False           False   False   False   False        0.7
# 3      False           False   False   False   False        0.7
# 4      False           False   False   False   False        1.0
#
#    alk_phosphate   sgot  albumin  protime  histology class
# 0           85.0   18.0      4.0      NaN      False  live
# 1          135.0   42.0      3.5      NaN      False  live
# 2           96.0   32.0      4.0      NaN      False  live
# 3           46.0   52.0      4.0     80.0      False  live
# 4            NaN  200.0      4.0      NaN      False  live

# %%
df.shape
# Out:
# (155, 20)

# %%
df.dtypes
# Out:
# age                  int64
# sex                 object
# steroid             object
# antivirals            bool
# fatigue             object
# malaise             object
# anorexia            object
# liver_big           object
# liver_firm          object
# spleen_palpable     object
# spiders             object
# ascites             object
# varices             object
# bilirubin          float64
# alk_phosphate      float64
# sgot               float64
# albumin            float64
# protime            float64
# histology             bool
# class               object
# dtype: object

# %%
# CONVER ALL TYPES
df = df.convert_dtypes()
df.dtypes
# Out:
# age                         Int64
# sex                string[python]
# steroid                   boolean
# antivirals                boolean
# fatigue                   boolean
# malaise                   boolean
# anorexia                  boolean
# liver_big                 boolean
# liver_firm                boolean
# spleen_palpable           boolean
# spiders                   boolean
# ascites                   boolean
# varices                   boolean
# bilirubin                 Float64
# alk_phosphate               Int64
# sgot                        Int64
# albumin                   Float64
# protime                     Int64
# histology                 boolean
# class              string[python]
# dtype: object

# %%
df.head(5)
# Out:
#    age     sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 0   30    male    False       False    False    False     False      False
# 1   50  female    False       False     True    False     False      False
# 2   78  female     True       False     True    False     False       True
# 3   31  female     <NA>        True    False    False     False       True
# 4   34  female     True       False    False    False     False       True
#
#    liver_firm  spleen_palpable  spiders  ascites  varices  bilirubin  \
# 0       False            False    False    False    False        1.0
# 1       False            False    False    False    False        0.9
# 2       False            False    False    False    False        0.7
# 3       False            False    False    False    False        0.7
# 4       False            False    False    False    False        1.0
#
#    alk_phosphate  sgot  albumin  protime  histology class
# 0             85    18      4.0     <NA>      False  live
# 1            135    42      3.5     <NA>      False  live
# 2             96    32      4.0     <NA>      False  live
# 3             46    52      4.0       80      False  live
# 4           <NA>   200      4.0     <NA>      False  live

# %%
# I dentify how many missing values there are
df.isna().sum()
# Out:
# age                 0
# sex                 0
# steroid             1
# antivirals          0
# fatigue             1
# malaise             1
# anorexia            1
# liver_big          10
# liver_firm         11
# spleen_palpable     5
# spiders             5
# ascites             5
# varices             5
# bilirubin           6
# alk_phosphate      29
# sgot                4
# albumin            16
# protime            67
# histology           0
# class               0
# dtype: int64

# %%
# We want to get the percentage fo Nan
df.isna().sum()/len(df) * 100
# Out:
# age                 0.000000
# sex                 0.000000
# steroid             0.645161
# antivirals          0.000000
# fatigue             0.645161
# malaise             0.645161
# anorexia            0.645161
# liver_big           6.451613
# liver_firm          7.096774
# spleen_palpable     3.225806
# spiders             3.225806
# ascites             3.225806
# varices             3.225806
# bilirubin           3.870968
# alk_phosphate      18.709677
# sgot                2.580645
# albumin            10.322581
# protime            43.225806
# histology           0.000000
# class               0.000000
# dtype: float64

# %% [markdown]
# # 2. Clean the dataset
# There are NaN values!
#
# We have three options:
#
# 1. drop variables with missing values
# 2. drop samples with missing values
# 3. replace missing value with synthetic value

# %% [markdown]
# ### case 1. Drop the veriables with missing values

# %%
# remove the Nan values
df.dropna(axis=0)[:5]
# Out:
#     age     sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 5    34  female     True       False    False    False     False       True
# 10   39  female    False        True    False    False     False      False
# 11   32  female     True        True     True    False     False       True
# 12   41  female     True        True     True    False     False       True
# 13   30  female     True       False     True    False     False       True
#
#     liver_firm  spleen_palpable  spiders  ascites  varices  bilirubin  \
# 5        False            False    False    False    False        0.9
# 10        True            False    False    False    False        1.3
# 11        True            False     True    False    False        1.0
# 12        True            False    False    False    False        0.9
# 13        True            False    False    False    False        2.2
#
#     alk_phosphate  sgot  albumin  protime  histology class
# 5              95    28      4.0       75      False  live
# 10             78    30      4.4       85      False  live
# 11             59   249      3.7       54      False  live
# 12             81    60      3.9       52      False  live
# 13             57   144      4.9       78      False  live

# %% [markdown]
# ### case 2. Drop samples with missing values

# %%
df.dropna(axis=1)[:5]
# Out:
#    age     sex  antivirals  histology class
# 0   30    male       False      False  live
# 1   50  female       False      False  live
# 2   78  female       False      False  live
# 3   31  female        True      False  live
# 4   34  female       False      False  live

# %%
# We can also delete variables only if the amount of nan is above a threshold
df.dropna(thresh=0.8*len(df),axis=1)[:5]
# Out:
#    age     sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 0   30    male    False       False    False    False     False      False
# 1   50  female    False       False     True    False     False      False
# 2   78  female     True       False     True    False     False       True
# 3   31  female     <NA>        True    False    False     False       True
# 4   34  female     True       False    False    False     False       True
#
#    liver_firm  spleen_palpable  spiders  ascites  varices  bilirubin  \
# 0       False            False    False    False    False        1.0
# 1       False            False    False    False    False        0.9
# 2       False            False    False    False    False        0.7
# 3       False            False    False    False    False        0.7
# 4       False            False    False    False    False        1.0
#
#    alk_phosphate  sgot  albumin  histology class
# 0             85    18      4.0      False  live
# 1            135    42      3.5      False  live
# 2             96    32      4.0      False  live
# 3             46    52      4.0      False  live
# 4           <NA>   200      4.0      False  live

# %% [markdown]
# ## Case 3 (preferred) - we want to insert generated values
#
# - In case of numerical values, we can replace the missing value with the average value of the column
# - In case of cathegorical values we can replace the missing value with the most frequent value of the column
#
# .fillna(value) replaces all the NaNs with values passed as argument

# %%
# Let's start with bollean columsn
# 1. Get columns that contain bolean value
boolean_cols = df.select_dtypes(include=bool).columns.tolist()
boolean_cols
# Out:
# ['steroid',
#  'antivirals',
#  'fatigue',
#  'malaise',
#  'anorexia',
#  'liver_big',
#  'liver_firm',
#  'spleen_palpable',
#  'spiders',
#  'ascites',
#  'varices',
#  'histology']

# %%
# 2. Get the most frequent value s
most_frequent_values = df[boolean_cols].mode().loc[0]
most_frequent_values
# Out:
# steroid             True
# antivirals         False
# fatigue             True
# malaise            False
# anorexia           False
# liver_big           True
# liver_firm         False
# spleen_palpable    False
# spiders            False
# ascites            False
# varices            False
# histology          False
# Name: 0, dtype: boolean

# %%
# Replace missing content with the mode
df[boolean_cols] = df[boolean_cols].fillna(most_frequent_values)
df[:5]
# Out:
#    age     sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 0   30    male    False       False    False    False     False      False
# 1   50  female    False       False     True    False     False      False
# 2   78  female     True       False     True    False     False       True
# 3   31  female     True        True    False    False     False       True
# 4   34  female     True       False    False    False     False       True
#
#    liver_firm  spleen_palpable  spiders  ascites  varices  bilirubin  \
# 0       False            False    False    False    False        1.0
# 1       False            False    False    False    False        0.9
# 2       False            False    False    False    False        0.7
# 3       False            False    False    False    False        0.7
# 4       False            False    False    False    False        1.0
#
#    alk_phosphate  sgot  albumin  protime  histology class
# 0             85    18      4.0     <NA>      False  live
# 1            135    42      3.5     <NA>      False  live
# 2             96    32      4.0     <NA>      False  live
# 3             46    52      4.0       80      False  live
# 4           <NA>   200      4.0     <NA>      False  live

# %% [markdown]
# #### Ingeger values

# %%
# 1. Get columns containing number
numeric = df.select_dtypes(include=int)
numeric[:5]
# Out:
#    age  alk_phosphate  sgot  protime
# 0   30             85    18     <NA>
# 1   50            135    42     <NA>
# 2   78             96    32     <NA>
# 3   31             46    52       80
# 4   34           <NA>   200     <NA>

# %%
# 2. integer columns
integer_columns = numeric.columns
integer_columns
# Out:
# Index(['age', 'alk_phosphate', 'sgot', 'protime'], dtype='object')

# %%
# find the median
median_of_integer_cols = df[integer_columns].median()
median_of_integer_cols
# Out:
# age              39.0
# alk_phosphate    85.0
# sgot             58.0
# protime          61.0
# dtype: Float64

# %%
# replace these columns with their median
df[integer_columns] = df[integer_columns].fillna(median_of_integer_cols)
df[:5]
# Out:
#    age     sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 0   30    male    False       False    False    False     False      False
# 1   50  female    False       False     True    False     False      False
# 2   78  female     True       False     True    False     False       True
# 3   31  female     True        True    False    False     False       True
# 4   34  female     True       False    False    False     False       True
#
#    liver_firm  spleen_palpable  spiders  ascites  varices  bilirubin  \
# 0       False            False    False    False    False        1.0
# 1       False            False    False    False    False        0.9
# 2       False            False    False    False    False        0.7
# 3       False            False    False    False    False        0.7
# 4       False            False    False    False    False        1.0
#
#    alk_phosphate  sgot  albumin  protime  histology class
# 0             85    18      4.0       61      False  live
# 1            135    42      3.5       61      False  live
# 2             96    32      4.0       61      False  live
# 3             46    52      4.0       80      False  live
# 4             85   200      4.0       61      False  live

# %% [markdown]
# #### Float columns

# %%
# lets's address the float columns
numeric = df.select_dtypes(include=float)
numeric_columns = numeric.columns
numeric_columns
# Out:
# Index(['bilirubin', 'albumin'], dtype='object')

# %%
# replace these columns with their median
# convert all floats64 to floats
df[numeric_columns] = df[numeric_columns].astype(float)

# %%
# interpolate
df[numeric_columns] = df[numeric_columns].interpolate(method='linear')

# %% [markdown]
# #### Categorical columns

# %%
 # get the cateforical columns
categorical_columns = df.select_dtypes(include='string').columns.tolist()
categorical_columns
# Out:
# ['sex', 'class']

# %%
# get the most frequent values
most_frequent_values = df[categorical_columns].mode()
most_frequent_values
# Out:
#       sex class
# 0  female  live

# %%
df[categorical_columns] = df[categorical_columns].fillna(most_frequent_values)

# %%
df[:4]
# Out:
#    age     sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 0   30    male    False       False    False    False     False      False
# 1   50  female    False       False     True    False     False      False
# 2   78  female     True       False     True    False     False       True
# 3   31  female     True        True    False    False     False       True
#
#    liver_firm  spleen_palpable  spiders  ascites  varices  bilirubin  \
# 0       False            False    False    False    False        1.0
# 1       False            False    False    False    False        0.9
# 2       False            False    False    False    False        0.7
# 3       False            False    False    False    False        0.7
#
#    alk_phosphate  sgot  albumin  protime  histology class
# 0             85    18      4.0       61      False  live
# 1            135    42      3.5       61      False  live
# 2             96    32      4.0       61      False  live
# 3             46    52      4.0       80      False  live

# %%
# Final check
df.isnull().values.any() # this should be False
# Out:
# np.False_

# %% [markdown]
# # 2. Encode the features
# We need to encode the target variable through labeling

# %%
# 1. initialize the label encoder
le = sklearn.preprocessing.LabelEncoder()

# %%
# 2. Encode the target class
# Fit convert string to number & transfor
df['class'] = le.fit_transform(df['class'])

# %% [markdown]
#  We need to encode cathegorical features through one-hot encoding

# %%
# get columns containing cathegorical features
categorical_features = df.select_dtypes(include='string').columns.tolist()
categorical_features
# Out:
# ['sex']

# %%
# one-hot encode the categorical features
df = pd.get_dummies(df, prefix=categorical_features)
df[:5]
# Out:
#    age  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 0   30    False       False    False    False     False      False
# 1   50    False       False     True    False     False      False
# 2   78     True       False     True    False     False       True
# 3   31     True        True    False    False     False       True
# 4   34     True       False    False    False     False       True
#
#    liver_firm  spleen_palpable  spiders  ...  varices  bilirubin  \
# 0       False            False    False  ...    False        1.0
# 1       False            False    False  ...    False        0.9
# 2       False            False    False  ...    False        0.7
# 3       False            False    False  ...    False        0.7
# 4       False            False    False  ...    False        1.0
#
#    alk_phosphate  sgot  albumin  protime  histology  class  sex_female  \
# 0             85    18      4.0       61      False      1       False
# 1            135    42      3.5       61      False      1        True
# 2             96    32      4.0       61      False      1        True
# 3             46    52      4.0       80      False      1        True
# 4             85   200      4.0       61      False      1        True
#
#    sex_male
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#
# [5 rows x 21 columns]

# %%
# 3. Let's find the ooutliers
# 3.1 isolation forests
# Initialized the isolation forest

isoforest = sklearn.ensemble.IsolationForest(n_estimators=1000, contamination=0.01, random_state=0)
# random_state=to stop randomness

# %%
# for each sample get an anomaly score
res = isoforest.fit_predict(df.to_numpy())
res[res==-1]
# Out:
# array([-1, -1])

# %%
# Find outliers with PCA
pca = sklearn.decomposition.PCA(n_components=0.9999)

# %%
# apply pca
X_pca = pca.fit_transform(df)

# %%
# invert pca
X_ori = pca.inverse_transform(X_pca)

# %%
#  define anomaly score as the sum of the absolute distances
anomaly_score = np.abs(df.to_numpy()-X_ori).sum(1)

# %%
anomaly_score
# Out:
# array([4.257120094857969, 3.483297673117139, 1.753849211656837,
#        1.9933958330522419, 1.254265844106791, 1.1694381613686615,
#        5.555806022682493, 1.0324252117221375, 2.9921763854531163,
#        1.2993078266405715, 3.416006343768003, 3.596288689332473,
#        3.3086025091232503, 3.3956802460224433, 2.5751272911672265,
#        3.200063554233521, 1.549763308884244, 3.22016012400328,
#        1.8985973388560002, 3.609386733941557, 3.7808480333459578,
#        4.2097689986864335, 0.9764544264680654, 1.1852112669328523,
#        4.277626832026586, 1.879344612588713, 4.15769005965371,
#        3.3217971389957683, 3.0384168362321864, 2.388175158723415,
#        5.004256515574848, 2.5814765040871905, 4.188555473411109,
#        3.613651285169248, 1.763836189722548, 3.8481916267463654,
#        2.550507982092612, 3.46631961507377, 1.5286656216488328,
#        3.263159731775886, 2.5565538904639373, 1.4896389919912882,
#        1.0604296995731897, 2.3648529264168165, 1.0180075434835052,
#        2.211476655319589, 3.624888583637744, 2.9077143982951554,
#        2.5963399510206617, 3.0959025842482206, 1.649399485872008,
#        1.4276300003395233, 1.2017286073055864, 4.052166265150036,
#        1.856644223187178, 1.856099082388837, 2.2650387025694863,
#        2.1514766301841792, 4.0621412088797335, 4.963612778967441,
#        1.1770822299651504, 1.0108146035907557, 3.999782872865971,
#        4.077905660540102, 2.578307846404651, 1.1064910116293833,
#        2.596279223770682, 3.4437169093096243, 2.0833850392223354,
#        2.075962989926773, 1.0041502418561363, 3.9706468766891563,
#        1.8050259345849642, 3.2058002094686775, 1.5142065411864216,
#        2.477017436983335, 4.830436894193632, 4.076822399256788,
#        3.4232941472783742, 0.8772433697301671, 1.7364862738673428,
#        1.5022194804313354, 1.4251944996401749, 2.79297140748779,
#        3.614879831302651, 3.195035508323656, 4.247958967948313,
#        2.645087356692486, 3.409859574059131, 3.236166611061592,
#        4.110664214654075, 3.4694274883683343, 2.0049914746498225,
#        2.1923276788469384, 3.4922549298002905, 4.0625900149750915,
#        3.12192941379692, 3.530015001904878, 3.9075888540613737,
#        2.8029647758066805, 3.58263096718512, 2.84864776588381,
#        3.301090884637968, 3.289305159974714, 4.054112865295962,
#        2.7300874439722205, 4.378251155875811, 1.9672399853113764,
#        3.595614268178556, 3.014676334524497, 2.69406751339614,
#        3.6509142265563095, 2.4492166528645782, 3.94725270291705,
#        1.6706621762543452, 4.201336777041469, 2.810862229131873,
#        1.9621492176532722, 2.8961575209245125, 4.201027945166006,
#        2.8195311110713903, 3.215212326985802, 3.1110719715786415,
#        3.5327321450358347, 2.9597466749216728, 4.769043682177875,
#        2.889177895961188, 3.7015807483909624, 2.948510876594014,
#        2.8440797929877237, 2.5325763163112502, 3.502401311102857,
#        2.6980744509066006, 4.449889932406508, 3.2639099405658984,
#        4.610068002852569, 2.719062236243053, 3.0801019204263396,
#        2.8828560495213518, 2.7303389718116975, 4.150629708418968,
#        3.6602071062177366, 3.1777355826718496, 3.5971603029411163,
#        2.8014430810971986, 2.5306565976150184, 2.987241671054477,
#        2.5077564951116207, 1.1871935799646764, 1.9663075540929913,
#        2.5627211653101374, 2.946694208197761, 2.46188392393381,
#        7.122252977300189, 3.7742593982471138], dtype=object)

# %%
threshold = np.quantile(anomaly_score, 0.99)

# get the ids of the anomalous values
anomalous_ids = np.argwhere(anomaly_score > threshold).squeeze()

# %%
df.iloc[anomalous_ids]
# Out:
#      age  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 6     51    False       False     True    False      True       True
# 153   53    False       False     True    False     False       True
#
#      liver_firm  spleen_palpable  spiders  ...  varices  bilirubin  \
# 6         False             True     True  ...    False       0.95
# 153       False             True     True  ...     True       1.50
#
#      alk_phosphate  sgot   albumin  protime  histology  class  sex_female  \
# 6               85    58  4.133333       61      False      0        True
# 153             81    19  4.100000       48       True      1       False
#
#      sex_male
# 6       False
# 153      True
#
# [2 rows x 21 columns]

# %%
# 4. Normalize the features
# split input variable from output variables
x = df[list(set(df.columns)-set(['class']))]
y = df['class']

# %%
# define standard scaler
scaler = sklearn.preprocessing.StandardScaler()
# normalize features
x = scaler.fit_transform(x)

# %%
# split train/ test

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=0)

# %%
x_train.shape, x_test.shape
# Out:
# ((124, 20), (31, 20))

# %% [markdown]
# ### Train random forest

# %%
rf = sklearn.ensemble.RandomForestClassifier(n_estimators=100)

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# predict on test set
y_estim = rf.predict(x_test)

# %%
conf_mat = sklearn.metrics.confusion_matrix(y_test, y_estim)
conf_mat
# Out:
# array([[ 4,  5],
#        [ 0, 22]])

# %%
# Comput the accuracy
acc = sklearn.metrics.accuracy_score(y_test, y_estim)
acc
# Out:
# 0.8387096774193549
