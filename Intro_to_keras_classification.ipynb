# %% [markdown]
# <a href="https://colab.research.google.com/github/nawroz-m/ML_learning/blob/environment/Intro_to_keras_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Intro to Keras and tensorflow
#
# Let's build a model to diagnose the diabetes disease based on generic information on the patient

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##Access the dataset and store it in a container

# %%
from google.colab import drive

drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
#access the dataset and store it in a panda dataframe
df = pd.read_csv('/content/drive/MyDrive/Environment/diabetes.csv')

#reshuffle the df rows
df = df.sample(frac = 1)

# %%
#print the first 5 rows
df[:5]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 396            3       96             56             34      115  24.7
# 203            2       99             70             16       44  20.4
# 181            0      119             64             18       92  34.9
# 100            1      163             72              0        0  39.0
# 354            3       90             78              0        0  42.7
#
#      DiabetesPedigreeFunction  Age  Outcome
# 396                     0.944   39        0
# 203                     0.235   27        0
# 181                     0.725   23        0
# 100                     1.222   33        1
# 354                     0.559   21        0

# %%
#print the number of rows and columns
df.shape
# Out:
# (768, 9)

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# #We notice that certain field contain null values, which is not expected in some case
#
# Let's try to remove those lines

# %%
zero_fields = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

fig, axes = plt.subplots(1, 5, figsize=(20, 5))

for ii in range(5):
  axes[ii].hist(df[zero_fields[ii]], bins=np.arange(min(df[zero_fields[ii]]), max(df[zero_fields[ii]]) + 1, 1), density=True)
  axes[ii].set_title(zero_fields[ii])
plt.tight_layout()
plt.show()

# %%
# lets fix the 0-entry for a field in the dataset with its mean value
def impute_zero_field(data, field):
    # Ensure the column is float to avoid FutureWarning when assigning mean values
    data[field] = data[field].astype(float)
    nonzero_vals = data.loc[data[field] != 0, field]
    avg = np.sum(nonzero_vals) / len(nonzero_vals)
    k = len(data.loc[ data[field] == 0, field])   # num of 0-entries
    data.loc[ data[field] == 0, field] = avg
    print('Field: %s; fixed %d entries with value: %.3f' % (field, k, avg))

# Fix it for Train dataset
for field in zero_fields:
    impute_zero_field(df, field)
# Out:
# Field: Glucose; fixed 5 entries with value: 121.687
# Field: BloodPressure; fixed 35 entries with value: 72.405
# Field: SkinThickness; fixed 227 entries with value: 29.153
# Field: Insulin; fixed 374 entries with value: 155.548
# Field: BMI; fixed 11 entries with value: 32.457

# %%
df.shape
# Out:
# (768, 9)

# %% [markdown]
# ##Manipulate the dataset and create the train and target variables

# %%
#define the target variable
target_column = ['Outcome']

#create the list of features, after excluding the target variable
predictors = list(set(list(df.columns))-set(target_column))

#normalize the features between 0 and 1 to reduce the influence of the predictor's units and magnitude on the modelling process.
df[predictors] = df[predictors]/df[predictors].max()


plt.hist(df['Glucose'])
# Out:
# (array([  4.,  19.,  87., 149., 161., 130.,  88.,  54.,  44.,  32.]),
#  array([0.22110553, 0.29899497, 0.37688442, 0.45477387, 0.53266332,
#         0.61055276, 0.68844221, 0.76633166, 0.84422111, 0.92211055,
#         1.        ]),
#  <BarContainer object of 10 artists>)

# %%
X = df[predictors].values
Y = df[target_column].values

#compute the fraction to be used for training and testing (keep 10% for further testing)
fraction = int(X.size/8*0.90)

X_train = X[:fraction,:]
X_test  = X[fraction:,:]

Y_train = Y[:fraction,:]
Y_test  = Y[fraction:,:]

#print(X_train.size, X_test.size)
#print(X_train,Y_train)

# %%
#import the needed libraries
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Input, Dropout
from tensorflow.keras import initializers
from keras.utils import to_categorical

# %% [markdown]
# ##Build the model

# %%
keras.optimizers?

# %%
model = Sequential()
model.add(Input((8,)))
model.add(Dense(64, activation='relu', kernel_initializer='random_normal', bias_initializer='zeros'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu', kernel_initializer='random_normal', bias_initializer='zeros'))
#model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid', kernel_initializer='random_normal', bias_initializer='zeros'))

# Compile the model
#lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
#    initial_learning_rate=1e-2,
#    decay_steps=10000,
#    decay_rate=0.9)

opt = keras.optimizers.Adam(learning_rate=0.001)  #Adam optimizer
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │           576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,689 (10.50 KB)
#  Trainable params: 2,689 (10.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
history = model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5906 - loss: 0.6920 - val_accuracy: 0.6547 - val_loss: 0.6883
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6560 - loss: 0.6870 - val_accuracy: 0.6547 - val_loss: 0.6826
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6495 - loss: 0.6816 - val_accuracy: 0.6547 - val_loss: 0.6753
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6561 - loss: 0.6737 - val_accuracy: 0.6547 - val_loss: 0.6669
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6879 - loss: 0.6571 - val_accuracy: 0.6547 - val_loss: 0.6592
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6369 - loss: 0.6674 - val_accuracy: 0.6547 - val_loss: 0.6560
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6412 - loss: 0.6627 - val_accuracy: 0.6547 - val_loss: 0.6538
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6583 - loss: 0.6540 - val_accuracy: 0.6547 - val_loss: 0.6520
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6306 - loss: 0.6645 - val_accuracy: 0.6547 - val_loss: 0.6496
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6273 - loss: 0.6648 - val_accuracy: 0.6547 - val_loss: 0.6471
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6629 - loss: 0.6408 - val_accuracy: 0.6547 - val_loss: 0.6446
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6527 - loss: 0.6467 - val_accuracy: 0.6547 - val_loss: 0.6407
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6637 - loss: 0.6355 - val_accuracy: 0.6547 - val_loss: 0.6368
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6931 - loss: 0.6171 - val_accuracy: 0.6547 - val_loss: 0.6323
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6526 - loss: 0.6316 - val_accuracy: 0.6547 - val_loss: 0.6271
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6594 - loss: 0.6194 - val_accuracy: 0.6547 - val_loss: 0.6203
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6389 - loss: 0.6253 - val_accuracy: 0.6619 - val_loss: 0.6137
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6648 - loss: 0.6158 - val_accuracy: 0.6547 - val_loss: 0.6068
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6857 - loss: 0.5952 - val_accuracy: 0.6547 - val_loss: 0.5997
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7177 - loss: 0.5783 - val_accuracy: 0.6619 - val_loss: 0.5920
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7136 - loss: 0.5834 - val_accuracy: 0.6691 - val_loss: 0.5847
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7198 - loss: 0.5656 - val_accuracy: 0.7050 - val_loss: 0.5773
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7293 - loss: 0.5704 - val_accuracy: 0.6835 - val_loss: 0.5719
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7012 - loss: 0.5643 - val_accuracy: 0.6978 - val_loss: 0.5651
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7349 - loss: 0.5501 - val_accuracy: 0.6978 - val_loss: 0.5594
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7162 - loss: 0.5449 - val_accuracy: 0.7194 - val_loss: 0.5560
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7211 - loss: 0.5487 - val_accuracy: 0.7122 - val_loss: 0.5505
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7208 - loss: 0.5385 - val_accuracy: 0.7266 - val_loss: 0.5475
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7580 - loss: 0.5147 - val_accuracy: 0.7266 - val_loss: 0.5441
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7645 - loss: 0.5010 - val_accuracy: 0.7338 - val_loss: 0.5403
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7277 - loss: 0.5352 - val_accuracy: 0.7410 - val_loss: 0.5373
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7485 - loss: 0.5127 - val_accuracy: 0.7410 - val_loss: 0.5348
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7656 - loss: 0.4813 - val_accuracy: 0.7338 - val_loss: 0.5339
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7605 - loss: 0.4944 - val_accuracy: 0.7554 - val_loss: 0.5303
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7489 - loss: 0.5129 - val_accuracy: 0.7482 - val_loss: 0.5278
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7563 - loss: 0.5123 - val_accuracy: 0.7338 - val_loss: 0.5264
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7696 - loss: 0.4898 - val_accuracy: 0.7338 - val_loss: 0.5239
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7461 - loss: 0.5038 - val_accuracy: 0.7554 - val_loss: 0.5221
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7539 - loss: 0.5100 - val_accuracy: 0.7554 - val_loss: 0.5203
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7355 - loss: 0.5088 - val_accuracy: 0.7482 - val_loss: 0.5185
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7300 - loss: 0.5012 - val_accuracy: 0.7626 - val_loss: 0.5172
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7717 - loss: 0.4674 - val_accuracy: 0.7482 - val_loss: 0.5167
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7550 - loss: 0.4981 - val_accuracy: 0.7410 - val_loss: 0.5179
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7740 - loss: 0.4724 - val_accuracy: 0.7554 - val_loss: 0.5123
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7502 - loss: 0.5008 - val_accuracy: 0.7554 - val_loss: 0.5107
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7804 - loss: 0.4754 - val_accuracy: 0.7554 - val_loss: 0.5107
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7511 - loss: 0.4884 - val_accuracy: 0.7554 - val_loss: 0.5079
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7360 - loss: 0.5093 - val_accuracy: 0.7482 - val_loss: 0.5076
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7683 - loss: 0.4881 - val_accuracy: 0.7554 - val_loss: 0.5063
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7497 - loss: 0.5006 - val_accuracy: 0.7626 - val_loss: 0.5043
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7581 - loss: 0.4903 - val_accuracy: 0.7482 - val_loss: 0.5061
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7748 - loss: 0.4742 - val_accuracy: 0.7482 - val_loss: 0.5031
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7798 - loss: 0.4544 - val_accuracy: 0.7482 - val_loss: 0.5019
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7705 - loss: 0.4629 - val_accuracy: 0.7482 - val_loss: 0.5021
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7523 - loss: 0.4893 - val_accuracy: 0.7482 - val_loss: 0.5006
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7528 - loss: 0.4732 - val_accuracy: 0.7626 - val_loss: 0.4994
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7858 - loss: 0.4564 - val_accuracy: 0.7554 - val_loss: 0.5000
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7747 - loss: 0.4627 - val_accuracy: 0.7554 - val_loss: 0.4991
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7766 - loss: 0.4580 - val_accuracy: 0.7554 - val_loss: 0.4984
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7906 - loss: 0.4669 - val_accuracy: 0.7626 - val_loss: 0.4967
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7540 - loss: 0.4924 - val_accuracy: 0.7626 - val_loss: 0.4956
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7710 - loss: 0.4613 - val_accuracy: 0.7554 - val_loss: 0.4968
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7678 - loss: 0.4669 - val_accuracy: 0.7554 - val_loss: 0.4939
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7841 - loss: 0.4567 - val_accuracy: 0.7626 - val_loss: 0.4944
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7673 - loss: 0.4606 - val_accuracy: 0.7554 - val_loss: 0.4934
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7657 - loss: 0.4572 - val_accuracy: 0.7626 - val_loss: 0.4920
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7692 - loss: 0.4629 - val_accuracy: 0.7698 - val_loss: 0.4916
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7513 - loss: 0.4926 - val_accuracy: 0.7698 - val_loss: 0.4912
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7702 - loss: 0.4546 - val_accuracy: 0.7626 - val_loss: 0.4922
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7718 - loss: 0.4653 - val_accuracy: 0.7554 - val_loss: 0.4932
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7609 - loss: 0.4759 - val_accuracy: 0.7626 - val_loss: 0.4919
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7811 - loss: 0.4674 - val_accuracy: 0.7698 - val_loss: 0.4897
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7556 - loss: 0.4733 - val_accuracy: 0.7770 - val_loss: 0.4880
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7490 - loss: 0.4834 - val_accuracy: 0.7626 - val_loss: 0.4928
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7731 - loss: 0.4542 - val_accuracy: 0.7770 - val_loss: 0.4881
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7723 - loss: 0.4709 - val_accuracy: 0.7626 - val_loss: 0.4921
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7769 - loss: 0.4646 - val_accuracy: 0.7770 - val_loss: 0.4868
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7546 - loss: 0.4852 - val_accuracy: 0.7698 - val_loss: 0.4878
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7568 - loss: 0.4871 - val_accuracy: 0.7626 - val_loss: 0.4881
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7404 - loss: 0.4819 - val_accuracy: 0.7770 - val_loss: 0.4870
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7567 - loss: 0.4725 - val_accuracy: 0.7554 - val_loss: 0.4923
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7839 - loss: 0.4491 - val_accuracy: 0.7698 - val_loss: 0.4869
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7489 - loss: 0.4653 - val_accuracy: 0.7626 - val_loss: 0.4866
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7877 - loss: 0.4370 - val_accuracy: 0.7698 - val_loss: 0.4879
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7875 - loss: 0.4480 - val_accuracy: 0.7626 - val_loss: 0.4876
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7744 - loss: 0.4646 - val_accuracy: 0.7626 - val_loss: 0.4900
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7653 - loss: 0.4563 - val_accuracy: 0.7626 - val_loss: 0.4877
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7717 - loss: 0.4477 - val_accuracy: 0.7626 - val_loss: 0.4883
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7762 - loss: 0.4531 - val_accuracy: 0.7626 - val_loss: 0.4873
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7588 - loss: 0.4779 - val_accuracy: 0.7626 - val_loss: 0.4862
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8185 - loss: 0.4229 - val_accuracy: 0.7626 - val_loss: 0.4873
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7599 - loss: 0.4592 - val_accuracy: 0.7626 - val_loss: 0.4872
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7901 - loss: 0.4543 - val_accuracy: 0.7698 - val_loss: 0.4856
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7857 - loss: 0.4387 - val_accuracy: 0.7626 - val_loss: 0.4843
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8019 - loss: 0.4372 - val_accuracy: 0.7698 - val_loss: 0.4858
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7834 - loss: 0.4529 - val_accuracy: 0.7626 - val_loss: 0.4854
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7729 - loss: 0.4741 - val_accuracy: 0.7626 - val_loss: 0.4850
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8034 - loss: 0.4280 - val_accuracy: 0.7698 - val_loss: 0.4837
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7688 - loss: 0.4622 - val_accuracy: 0.7554 - val_loss: 0.4867
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7666 - loss: 0.4714 - val_accuracy: 0.7698 - val_loss: 0.4813

# %% [markdown]
# ##Evaluate the model

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title('model loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'], label="Training accuracy")
plt.plot(history.history['val_accuracy'], label="Validation accuracy")
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
#predict the outcome on the test sample and plot the score
prediction_test = model.predict(X_test)
plt.hist(prediction_test, label='test dataset', alpha=.8, edgecolor='red', bins=np.arange(prediction_test.min(), prediction_test.max() + 0.1, 0.1), density=True)

#predict the outcome on the test sample and plot the score
prediction_train = model.predict(X_train)
plt.hist(prediction_train, label='train dataset', alpha=.8, edgecolor='yellow', bins=np.arange(prediction_test.min(), prediction_test.max() + 0.1, 0.1), density=True)

plt.legend()
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
print(prediction_test.max())
# Out:
# 0.93357664

# %%
#cast the score to a bool value
prediction_test_rounded = np.round(prediction_test) #cut the score in half
plt.hist(prediction_test_rounded, label='test dataset', alpha=.8, edgecolor='red', bins=np.arange(prediction_test_rounded.min(), prediction_test_rounded.max() + 0.2, 0.1), density=True)

prediction_train_rounded = np.round(prediction_train) #cut the score in half
plt.hist(prediction_train_rounded, label='train dataset', alpha=.7, edgecolor='yellow', bins=np.arange(prediction_test_rounded.min(), prediction_test_rounded.max() + 0.2, 0.1), density=True)

plt.legend()
plt.show()

# %%
diff_test = abs(prediction_test_rounded - Y_test)
print('Accuracy on test data: {}'.format(1 - np.sum(diff_test)/diff_test.size))

diff_train = abs(prediction_train_rounded - Y_train)
print('Accuracy on train data: {}'.format(1 - np.sum(diff_train)/diff_train.size))
# Out:
# Accuracy on test data: 0.7922077922077921
# Accuracy on train data: 0.7756874095513748

# %%
from sklearn.metrics import roc_curve, auc, confusion_matrix, ConfusionMatrixDisplay

# %%
fpr, tpr, thresholds = roc_curve(Y_test, prediction_test)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()

# %%
cm = confusion_matrix(Y_test, prediction_test_rounded)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])

fig, ax = plt.subplots(figsize=(6, 6))
disp.plot(cmap=plt.cm.Blues, ax=ax)
plt.title('Confusion Matrix')
plt.show()
